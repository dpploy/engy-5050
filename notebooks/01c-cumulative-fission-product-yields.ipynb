# %% [markdown]
# Engy-5050: Nuclear Reactor Physics Spring 2022 UMass Lowell; Prof. V. F. de Almeida **19Jan22**
#
# # 01c. Nuclear Data Processing: Cumulative Fission Product Yields
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\zerovec}{\boldsymbol{\mathsf{0}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \newcommand{\abs}[1]{\left\lvert{#1}\right\rvert}
#   \newcommand{\transpose}[1]{{#1}^\top}
#   \DeclareMathOperator{\rank}{rank}
# $

# %% [markdown]
# ---
# ## Table of Contents
# * [Objectives](#obj)
# * [Introduction](#intro)
# * [Cumulative (Decayed) fission fragment yield (A,Z)](#cffyaz)
# * [Data sets](#dataset)
# * [Cumulative fission products half-life times](#cfphalflife)
# ---

# %% [markdown]
# ## Objectives<a id="obj"></a>
# + Demonstrate how to obtain traceable nuclear data and have them available through the notebook for analysis and problem solving.
# + Explore alternative sources of data and their data mining.

# %% [markdown]
# ## Introduction<a id="intro"></a>
#
# Refer to Notebook 01.

# %% [markdown]
# ## Independent and cumulative (decayed) fission fragment yield (A,Z)<a id="cffyaz"></a>
#
# Acquiring the data:
#
# + This data is from `ENDF/B-VIII.0,Ei=0.0253eV` which is the same data base used in the Notebook 02b, but was acquired from a **third-party evaluation**.
# + *This data combines the independent and cumulative FPY in one file and it also includes the half-life of the FP*.
# + The data also includes both Z and A numbers of the nuclides and whether they are metastable.

# %% [markdown]
# ## Data sets<a id="dataset"></a>
#
# The following data sets are available:
#  + `u-235-fpy-AZ-thermal.csv`
#  + `u-233-fpy-AZ-thermal.csv`
#  + `pu-239-fpy-AZ-thermal.csv`

# %%
'''Select data set'''

data_set = 'u-235-fpy-AZ-thermal.csv'

# %%
'''View the raw data (edit the file name)'''

# !head -n 5 data/u-235-fpy-AZ-thermal.csv
print('...')
# !tail -n 5 data/u-235-fpy-AZ-thermal.csv
# Out:
# Compare,Nuclide,Half-lives,Ind. Yield(% per fiss.),Cum. Yield(% per fiss.)
# Compare,54 Xe 134,,0.0105,7.87
# Compare,53 I 134,52.5 m,0.500,7.83
# Compare,52 Te 134,41.8 m,6.22,6.97
# Compare,56 Ba 138,Stable,4.12e-3,6.77
# ...
# Compare,71 Lu 171m,79 s,no data,no data
# Compare,71 Lu 172,6.70 d,no data,no data
# Compare,71 Lu 172m,3.7 m,no data,no data
# Compare,72 Hf 171,12.1 h,no data,no data
# Compare,72 Hf 172,1.87 y,no data,no data

# %%
'''Function to read the blank-spaced column data into a Pandas data frame (table)'''

def read_table(file_name):
    '''
    Read table data into a `pandas` data frame (table).  
    
    Parameters
    ----------
    file_name: str, required
        File name and its path relative to this notebook.
    
    Returns
    -------
    df: pandas.df
        `Pandas` data frame (table).

    Examples
    --------
    '''
    import pandas as pd
    
    df = pd.read_csv( file_name,  
                      skiprows=0,
                      delim_whitespace=False)
    
    df.fillna('0 s',inplace=True)
    
# to avoid frustrations, set explicitly the data types of each column
    #for c in df.columns: 
        #if c == 'Y(NO-DIM)':
            #continue
        #df = df.astype({c:float},copy=False)

    #print(df.dtypes)
    return df

# %%
'''Read data'''

fpy_az_df = read_table('data/'+data_set)

# %%
'''A peek on the raw data'''

fpy_az_df
# Out:
#       Compare     Nuclide Half-lives Ind. Yield(% per fiss.)  \
# 0     Compare   54 Xe 134        0 s                  0.0105
# 1     Compare    53 I 134     52.5 m                   0.500
# 2     Compare   52 Te 134     41.8 m                    6.22
# 3     Compare   56 Ba 138     Stable                 4.12e-3
# 4     Compare   55 Cs 138    33.41 m                   0.243
# ...       ...         ...        ...                     ...
# 1242  Compare  71 Lu 171m       79 s                 no data
# 1243  Compare   71 Lu 172     6.70 d                 no data
# 1244  Compare  71 Lu 172m      3.7 m                 no data
# 1245  Compare   72 Hf 171     12.1 h                 no data
# 1246  Compare   72 Hf 172     1.87 y                 no data
#
#      Cum. Yield(% per fiss.)
# 0                       7.87
# 1                       7.83
# 2                       6.97
# 3                       6.77
# 4                       6.71
# ...                      ...
# 1242                 no data
# 1243                 no data
# 1244                 no data
# 1245                 no data
# 1246                 no data
#
# [1247 rows x 5 columns]

# %%
'''Function for creating a FP yield(A,Z) list container'''

def get_fpy_az( df ):
    '''
    Create a list of named tuple nuclides
    Parameters
    ----------
    df: pandas data frame, required
        Table of data for nuclides.
    
    Returns
    -------
    nuclides: list(namedtuple)
        List of namedtuples. Names: name, element_name, Z, A, half_life, independent_yield_percent, cumulative_yield_percent.

    Examples
    --------
    '''
    
    nuclides = list()

    # design a container data structure
    from collections import namedtuple
    FPY = namedtuple('FPY', ['name','element_name','Z','A','half_life','independent_yield_percent','cumulative_yield_percent'])

    import pandas as pd

    # Use the Mendeleev python package (periodic table of elements)
    from mendeleev import element
    
    total_cumulative_yield = 0.0 # sum total yield
    total_independent_yield = 0.0
    
    for row in df.itertuples(index=False):
        
        if row[2].strip() == 'Stable': # skip all stable FP
            continue
            
        assert isinstance(row[1],str),'row[1] = %r'%row[1]
        
        col1 = row[1].strip().split(' ')
        assert len(col1) == 3,'col1 = %r'%col1 # must have 3 elements
        
        z = int(col1[0])
        symbol = col1[1]
        
        if col1[2][-1] == 'm':
            a = int(col1[2][0:-1])
            nuclide_name = symbol + '-' + str(a) + 'm'
        elif col1[2][-1] == 'n':
            a = int(col1[2][0:-1])
            nuclide_name = symbol + '-' + str(a) + 'n'
        else:
            a = int(col1[2]) 
            nuclide_name = symbol+'-'+str(a)
        
        assert isinstance(row[2],str),'row[2] = %r'%row[2]
        
        col2 = row[2].strip().split(' ')
        assert len(col2) == 2,'col2 = %r'%col2
        
        half_life_unit = col2[1]
        
        # convert all values to second
        if half_life_unit == 'ns':
            half_life = float(col2[0])*1e-9
        elif half_life_unit == 'ms':
            half_life = float(col2[0])*1e-3
        elif half_life_unit == 's':
            half_life = float(col2[0])
        elif half_life_unit == 'm':
            half_life = float(col2[0])*60
        elif half_life_unit == 'h':
            half_life = float(col2[0])*60*60
        elif half_life_unit == 'd':
            half_life = float(col2[0])*60*60*24
        elif half_life_unit == 'y':
            half_life = float(col2[0])*60*60*24*365
        elif half_life_unit == 'ky':
            half_life = float(col2[0])*60*60*24*365*1e+3
        elif half_life_unit == 'My':
            half_life = float(col2[0])*60*60*24*365*1e+6
        elif half_life_unit == 'Gy':
            half_life = float(col2[0])*60*60*24*365*1e+9
        else:
            assert False,'unit = %r'%half_life_unit
        
        assert isinstance(row[3],str),'row[3] = %r'%row[3]
        if row[3].strip() == 'no data':
            independent_yield_value = 0.0
        else:
            independent_yield_value = float(row[3])
        total_independent_yield += independent_yield_value
        
        assert isinstance(row[4],str),'row[4] = %r'%row[4]
        if row[4].strip() == 'no data':
            cumulative_yield_value = 0.0
        else:
            cumulative_yield_value = float(row[4])
        total_cumulative_yield += cumulative_yield_value
        
        element_name = element(z).name
        
        nuc = FPY( name=nuclide_name, element_name=element_name, Z=z, A=a, 
                   half_life=half_life,
                   independent_yield_percent=independent_yield_value,
                   cumulative_yield_percent=cumulative_yield_value )
        
        nuclides.append(nuc)
            
    print('Sum of independent yield values in data file = ',round(total_independent_yield,2))
    print('Sum of cumulative  yield values in data file = ',round(total_cumulative_yield,2))
    return nuclides

# %%
'''Importing the mendeleev package'''

try:
    import mendeleev  # creates the `name` mendeleev
except ImportError:
    print('Installing the "mendeleev" package...')
    print('')
    # !pip install mendeleev
    import mendeleev

# %%
'''Create the FP yield(A,Z) list container'''

fpy_az = get_fpy_az( fpy_az_df )

print('Sum of independent yield values in dictionary container = ',round(sum([fp.independent_yield_percent for fp in fpy_az]),2))
print('Sum of cumulative  yield values in dictionary container = ',round(sum([fp.cumulative_yield_percent for fp in fpy_az]),2))
print('# of FP nuclides = ', len(fpy_az))
# Out:
# Sum of independent yield values in data file =  199.86
# Sum of cumulative  yield values in data file =  685.2
# Sum of independent yield values in dictionary container =  199.86
# Sum of cumulative  yield values in dictionary container =  685.2
# # of FP nuclides =  1111

# %%
'''Some info on the nuclide data structure just created'''

fpy_az
# Out:
# [FPY(name='Xe-134', element_name='Xenon', Z=54, A=134, half_life=0.0, independent_yield_percent=0.0105, cumulative_yield_percent=7.87),
#  FPY(name='I-134', element_name='Iodine', Z=53, A=134, half_life=3150.0, independent_yield_percent=0.5, cumulative_yield_percent=7.83),
#  FPY(name='Te-134', element_name='Tellurium', Z=52, A=134, half_life=2508.0, independent_yield_percent=6.22, cumulative_yield_percent=6.97),
#  FPY(name='Cs-138', element_name='Cesium', Z=55, A=138, half_life=2004.6, independent_yield_percent=0.243, cumulative_yield_percent=6.71),
#  FPY(name='Xe-133', element_name='Xenon', Z=54, A=133, half_life=452995.20000000007, independent_yield_percent=0.000666, cumulative_yield_percent=6.7),
#  FPY(name='I-133', element_name='Iodine', Z=53, A=133, half_life=74880.0, independent_yield_percent=0.0825, cumulative_yield_percent=6.7),
#  FPY(name='Cs-135', element_name='Cesium', Z=55, A=135, half_life=72532800000000.0, independent_yield_percent=0.000245, cumulative_yield_percent=6.54),
#  FPY(name='Xe-135', element_name='Xenon', Z=54, A=135, half_life=32904.00000000001, independent_yield_percent=0.0785, cumulative_yield_percent=6.54),
#  FPY(name='Nb-95', element_name='Niobium', Z=41, A=95, half_life=3023222.4000000004, independent_yield_percent=0.000106, cumulative_yield_percent=6.5),
#  FPY(name='Zr-95', element_name='Zirconium', Z=40, A=95, half_life=5532364.8, independent_yield_percent=0.127, cumulative_yield_percent=6.5),
#  FPY(name='Y-94', element_name='Yttrium', Z=39, A=94, half_life=1122.0, independent_yield_percent=0.39, cumulative_yield_percent=6.45),
#  FPY(name='Ba-139', element_name='Barium', Z=56, A=139, half_life=4983.6, independent_yield_percent=0.0688, cumulative_yield_percent=6.41),
#  FPY(name='Y-95', element_name='Yttrium', Z=39, A=95, half_life=618.0, independent_yield_percent=1.11, cumulative_yield_percent=6.38),
#  FPY(name='Zr-93', element_name='Zirconium', Z=40, A=93, half_life=48250080000000.0, independent_yield_percent=0.000137, cumulative_yield_percent=6.35),
#  FPY(name='Y-93', element_name='Yttrium', Z=39, A=93, half_life=36648.0, independent_yield_percent=0.0543, cumulative_yield_percent=6.35),
#  FPY(name='Cs-139', element_name='Cesium', Z=55, A=139, half_life=556.1999999999999, independent_yield_percent=1.31, cumulative_yield_percent=6.34),
#  FPY(name='Zr-96', element_name='Zirconium', Z=40, A=96, half_life=6.307200000000001e+26, independent_yield_percent=0.337, cumulative_yield_percent=6.34),
#  FPY(name='Xe-136', element_name='Xenon', Z=54, A=136, half_life=0.0, independent_yield_percent=2.19, cumulative_yield_percent=6.31),
#  FPY(name='Xe-138', element_name='Xenon', Z=54, A=138, half_life=844.8, independent_yield_percent=4.81, cumulative_yield_percent=6.3),
#  FPY(name='Mo-100', element_name='Molybdenum', Z=42, A=100, half_life=2.3021279999999997e+26, independent_yield_percent=0.0729, cumulative_yield_percent=6.29),
#  FPY(name='I-135', element_name='Iodine', Z=53, A=135, half_life=23652.000000000004, independent_yield_percent=2.93, cumulative_yield_percent=6.28),
#  FPY(name='Sr-93', element_name='Strontium', Z=38, A=93, half_life=445.38, independent_yield_percent=2.57, cumulative_yield_percent=6.24),
#  FPY(name='La-140', element_name='Lanthanum', Z=57, A=140, half_life=145026.72, independent_yield_percent=0.00522, cumulative_yield_percent=6.22),
#  FPY(name='Ba-140', element_name='Barium', Z=56, A=140, half_life=1101833.28, independent_yield_percent=0.488, cumulative_yield_percent=6.21),
#  FPY(name='Cs-137', element_name='Cesium', Z=55, A=137, half_life=948602880.0, independent_yield_percent=0.06, cumulative_yield_percent=6.19),
#  FPY(name='Xe-137', element_name='Xenon', Z=54, A=137, half_life=229.08, independent_yield_percent=3.19, cumulative_yield_percent=6.13),
#  FPY(name='Mo-99', element_name='Molybdenum', Z=42, A=99, half_life=237513.59999999998, independent_yield_percent=0.0428, cumulative_yield_percent=6.11),
#  FPY(name='Tc-99', element_name='Technetium', Z=43, A=99, half_life=6657249600000.0, independent_yield_percent=1.23e-07, cumulative_yield_percent=6.11),
#  FPY(name='Sr-94', element_name='Strontium', Z=38, A=94, half_life=75.3, independent_yield_percent=4.51, cumulative_yield_percent=6.06),
#  FPY(name='Nb-93m', element_name='Niobium', Z=41, A=93, half_life=508675680.0, independent_yield_percent=8.49e-10, cumulative_yield_percent=6.03),
#  FPY(name='Y-92', element_name='Yttrium', Z=39, A=92, half_life=12744.0, independent_yield_percent=0.0715, cumulative_yield_percent=6.01),
#  FPY(name='Y-96', element_name='Yttrium', Z=39, A=96, half_life=5.34, independent_yield_percent=0.224, cumulative_yield_percent=6.0),
#  FPY(name='Nb-97', element_name='Niobium', Z=41, A=97, half_life=4326.0, independent_yield_percent=0.0108, cumulative_yield_percent=6.0),
#  FPY(name='Zr-97', element_name='Zirconium', Z=40, A=97, half_life=60296.399999999994, independent_yield_percent=1.09, cumulative_yield_percent=5.98),
#  FPY(name='Ce-143', element_name='Cerium', Z=58, A=143, half_life=118940.40000000001, independent_yield_percent=0.0313, cumulative_yield_percent=5.96),
#  FPY(name='Pr-143', element_name='Praseodymium', Z=59, A=143, half_life=1172448.0, independent_yield_percent=4.5e-07, cumulative_yield_percent=5.96),
#  FPY(name='Sr-92', element_name='Strontium', Z=38, A=92, half_life=9756.0, independent_yield_percent=1.08, cumulative_yield_percent=5.94),
#  FPY(name='La-143', element_name='Lanthanum', Z=57, A=143, half_life=852.0, independent_yield_percent=0.379, cumulative_yield_percent=5.92),
#  FPY(name='Ba-137m', element_name='Barium', Z=56, A=137, half_life=153.12, independent_yield_percent=0.000133, cumulative_yield_percent=5.85),
#  FPY(name='Ce-142', element_name='Cerium', Z=58, A=142, half_life=0.0, independent_yield_percent=0.000176, cumulative_yield_percent=5.85),
#  FPY(name='La-142', element_name='Lanthanum', Z=57, A=142, half_life=5466.0, independent_yield_percent=0.0965, cumulative_yield_percent=5.85),
#  FPY(name='Ce-141', element_name='Cerium', Z=58, A=141, half_life=2808691.2, independent_yield_percent=4.99e-06, cumulative_yield_percent=5.85),
#  FPY(name='La-141', element_name='Lanthanum', Z=57, A=141, half_life=14112.0, independent_yield_percent=0.0185, cumulative_yield_percent=5.85),
#  FPY(name='Ba-141', element_name='Barium', Z=56, A=141, half_life=1096.2, independent_yield_percent=1.66, cumulative_yield_percent=5.83),
#  FPY(name='Y-91', element_name='Yttrium', Z=39, A=91, half_life=5055264.0, independent_yield_percent=0.000165, cumulative_yield_percent=5.83),
#  FPY(name='Sr-91', element_name='Strontium', Z=38, A=91, half_life=34668.00000000001, independent_yield_percent=0.25, cumulative_yield_percent=5.83),
#  FPY(name='Sr-90', element_name='Strontium', Z=38, A=90, half_life=907921439.9999999, independent_yield_percent=0.0737, cumulative_yield_percent=5.78),
#  FPY(name='Y-90', element_name='Yttrium', Z=39, A=90, half_life=230400.0, independent_yield_percent=4.48e-06, cumulative_yield_percent=5.78),
#  FPY(name='Ba-142', element_name='Barium', Z=56, A=142, half_life=636.0, independent_yield_percent=3.01, cumulative_yield_percent=5.75),
#  FPY(name='Nb-98', element_name='Niobium', Z=41, A=98, half_life=2.86, independent_yield_percent=0.116, cumulative_yield_percent=5.75),
#  FPY(name='Cs-140', element_name='Cesium', Z=55, A=140, half_life=63.7, independent_yield_percent=2.07, cumulative_yield_percent=5.72),
#  FPY(name='Zr-98', element_name='Zirconium', Z=40, A=98, half_life=30.7, independent_yield_percent=2.57, cumulative_yield_percent=5.64),
#  FPY(name='Zr-99', element_name='Zirconium', Z=40, A=99, half_life=2.1, independent_yield_percent=3.58, cumulative_yield_percent=5.63),
#  FPY(name='Nb-97m', element_name='Niobium', Z=41, A=97, half_life=58.7, independent_yield_percent=0.00245, cumulative_yield_percent=5.63),
#  FPY(name='Zr-100', element_name='Zirconium', Z=40, A=100, half_life=7.1, independent_yield_percent=4.98, cumulative_yield_percent=5.58),
#  FPY(name='Rb-91', element_name='Rubidium', Z=37, A=91, half_life=58.4, independent_yield_percent=2.22, cumulative_yield_percent=5.58),
#  FPY(name='Ba-143', element_name='Barium', Z=56, A=143, half_life=14.5, independent_yield_percent=4.1, cumulative_yield_percent=5.54),
#  FPY(name='Nd-144', element_name='Neodymium', Z=60, A=144, half_life=7.221744e+22, independent_yield_percent=9.57e-09, cumulative_yield_percent=5.5),
#  FPY(name='Ce-144', element_name='Cerium', Z=58, A=144, half_life=24616224.000000004, independent_yield_percent=0.0345, cumulative_yield_percent=5.5),
#  FPY(name='Pr-144', element_name='Praseodymium', Z=59, A=144, half_life=1036.8000000000002, independent_yield_percent=1.43e-06, cumulative_yield_percent=5.5),
#  FPY(name='La-144', element_name='Lanthanum', Z=57, A=144, half_life=40.8, independent_yield_percent=1.07, cumulative_yield_percent=5.47),
#  FPY(name='Tc-99m', element_name='Technetium', Z=43, A=99, half_life=21624.120000000003, independent_yield_percent=2.89e-08, cumulative_yield_percent=5.38),
#  FPY(name='Sr-95', element_name='Strontium', Z=38, A=95, half_life=23.9, independent_yield_percent=4.54, cumulative_yield_percent=5.27),
#  FPY(name='Tc-101', element_name='Technetium', Z=43, A=101, half_life=852.0, independent_yield_percent=0.000161, cumulative_yield_percent=5.17),
#  FPY(name='Mo-101', element_name='Molybdenum', Z=42, A=101, half_life=876.5999999999999, independent_yield_percent=0.186, cumulative_yield_percent=5.17),
#  FPY(name='Xe-139', element_name='Xenon', Z=54, A=139, half_life=39.68, independent_yield_percent=4.32, cumulative_yield_percent=5.04),
#  FPY(name='Nb-101', element_name='Niobium', Z=41, A=101, half_life=7.1, independent_yield_percent=1.92, cumulative_yield_percent=4.99),
#  FPY(name='Y-97', element_name='Yttrium', Z=39, A=97, half_life=3.75, independent_yield_percent=1.57, cumulative_yield_percent=4.89),
#  FPY(name='Kr-90', element_name='Krypton', Z=36, A=90, half_life=32.32, independent_yield_percent=4.4, cumulative_yield_percent=4.86),
#  FPY(name='Rb-92', element_name='Rubidium', Z=37, A=92, half_life=4.492, independent_yield_percent=3.13, cumulative_yield_percent=4.82),
#  FPY(name='Sr-89', element_name='Strontium', Z=38, A=89, half_life=4365792.0, independent_yield_percent=0.0175, cumulative_yield_percent=4.73),
#  FPY(name='Rb-89', element_name='Rubidium', Z=37, A=89, half_life=909.0, independent_yield_percent=0.205, cumulative_yield_percent=4.72),
#  FPY(name='Kr-89', element_name='Krypton', Z=36, A=89, half_life=189.0, independent_yield_percent=3.44, cumulative_yield_percent=4.51),
#  FPY(name='Rb-90', element_name='Rubidium', Z=37, A=90, half_life=158.0, independent_yield_percent=0.139, cumulative_yield_percent=4.5),
#  FPY(name='Ba-144', element_name='Barium', Z=56, A=144, half_life=11.5, independent_yield_percent=3.97, cumulative_yield_percent=4.4),
#  FPY(name='I-132', element_name='Iodine', Z=53, A=132, half_life=8262.0, independent_yield_percent=0.00913, cumulative_yield_percent=4.31),
#  FPY(name='Te-132', element_name='Tellurium', Z=52, A=132, half_life=276825.60000000003, independent_yield_percent=1.53, cumulative_yield_percent=4.29),
#  FPY(name='Tc-102m', element_name='Technetium', Z=43, A=102, half_life=261.0, independent_yield_percent=0.00955, cumulative_yield_percent=4.29),
#  FPY(name='Mo-102', element_name='Molybdenum', Z=42, A=102, half_life=678.0, independent_yield_percent=0.651, cumulative_yield_percent=4.28),
#  FPY(name='Cs-141', element_name='Cesium', Z=55, A=141, half_life=24.84, independent_yield_percent=2.92, cumulative_yield_percent=4.17),
#  FPY(name='Te-133m', element_name='Tellurium', Z=52, A=133, half_life=3324.0, independent_yield_percent=2.99, cumulative_yield_percent=3.99),
#  FPY(name='Nb-99', element_name='Niobium', Z=41, A=99, half_life=15.0, independent_yield_percent=0.03, cumulative_yield_percent=3.97),
#  FPY(name='Pr-145', element_name='Praseodymium', Z=59, A=145, half_life=21542.4, independent_yield_percent=0.000333, cumulative_yield_percent=3.93),
#  FPY(name='Ce-145', element_name='Cerium', Z=58, A=145, half_life=180.6, independent_yield_percent=0.0854, cumulative_yield_percent=3.93),
#  FPY(name='La-145', element_name='Lanthanum', Z=57, A=145, half_life=24.8, independent_yield_percent=1.91, cumulative_yield_percent=3.85),
#  FPY(name='Sr-96', element_name='Strontium', Z=38, A=96, half_life=1.07, independent_yield_percent=3.57, cumulative_yield_percent=3.76),
#  FPY(name='Xe-140', element_name='Xenon', Z=54, A=140, half_life=13.6, independent_yield_percent=3.51, cumulative_yield_percent=3.65),
#  FPY(name='Rb-88', element_name='Rubidium', Z=37, A=88, half_life=1066.3799999999999, independent_yield_percent=0.0223, cumulative_yield_percent=3.57),
#  FPY(name='Kr-88', element_name='Krypton', Z=36, A=88, half_life=10223.999999999998, independent_yield_percent=1.73, cumulative_yield_percent=3.55),
#  FPY(name='Rb-93', element_name='Rubidium', Z=37, A=93, half_life=5.84, independent_yield_percent=3.07, cumulative_yield_percent=3.55),
#  FPY(name='Y-91m', element_name='Yttrium', Z=39, A=91, half_life=2982.6, independent_yield_percent=0.000165, cumulative_yield_percent=3.38),
#  FPY(name='Kr-91', element_name='Krypton', Z=36, A=91, half_life=8.57, independent_yield_percent=3.16, cumulative_yield_percent=3.35),
#  FPY(name='Te-135', element_name='Tellurium', Z=52, A=135, half_life=19.0, independent_yield_percent=3.22, cumulative_yield_percent=3.34),
#  FPY(name='Nb-100', element_name='Niobium', Z=41, A=100, half_life=1.5, independent_yield_percent=0.319, cumulative_yield_percent=3.11),
#  FPY(name='Nb-100m', element_name='Niobium', Z=41, A=100, half_life=2.99, independent_yield_percent=0.319, cumulative_yield_percent=3.11),
#  FPY(name='Zr-101', element_name='Zirconium', Z=40, A=101, half_life=2.3, independent_yield_percent=2.79, cumulative_yield_percent=3.07),
#  FPY(name='I-137', element_name='Iodine', Z=53, A=137, half_life=24.5, independent_yield_percent=2.62, cumulative_yield_percent=3.07),
#  FPY(name='Te-133', element_name='Tellurium', Z=52, A=133, half_life=750.0, independent_yield_percent=1.15, cumulative_yield_percent=3.06),
#  FPY(name='Ru-103', element_name='Ruthenium', Z=44, A=103, half_life=3390940.8000000003, independent_yield_percent=2.36e-05, cumulative_yield_percent=3.03),
#  FPY(name='Tc-103', element_name='Technetium', Z=43, A=103, half_life=54.2, independent_yield_percent=0.0822, cumulative_yield_percent=3.03),
#  FPY(name='Rh-103m', element_name='Rhodium', Z=45, A=103, half_life=3366.8399999999997, independent_yield_percent=4.27e-10, cumulative_yield_percent=3.0),
#  FPY(name='Pr-146', element_name='Praseodymium', Z=59, A=146, half_life=1449.0, independent_yield_percent=0.00362, cumulative_yield_percent=3.0),
#  FPY(name='Ce-146', element_name='Cerium', Z=58, A=146, half_life=811.1999999999999, independent_yield_percent=0.583, cumulative_yield_percent=2.99),
#  FPY(name='Mo-103', element_name='Molybdenum', Z=42, A=103, half_life=67.5, independent_yield_percent=1.04, cumulative_yield_percent=2.95),
#  FPY(name='I-131', element_name='Iodine', Z=53, A=131, half_life=693377.28, independent_yield_percent=0.00392, cumulative_yield_percent=2.89),
#  FPY(name='Nb-102', element_name='Niobium', Z=41, A=102, half_life=4.3, independent_yield_percent=0.789, cumulative_yield_percent=2.84),
#  FPY(name='Cs-142', element_name='Cesium', Z=55, A=142, half_life=1.684, independent_yield_percent=2.28, cumulative_yield_percent=2.72),
#  FPY(name='I-136', element_name='Iodine', Z=53, A=136, half_life=83.39999999999999, independent_yield_percent=1.32, cumulative_yield_percent=2.64),
#  FPY(name='Rb-87', element_name='Rubidium', Z=37, A=87, half_life=1.5168816e+18, independent_yield_percent=0.0025, cumulative_yield_percent=2.56),
#  FPY(name='Kr-87', element_name='Krypton', Z=36, A=87, half_life=4578.0, independent_yield_percent=0.463, cumulative_yield_percent=2.56),
#  FPY(name='Sb-131', element_name='Antimony', Z=51, A=131, half_life=1381.8000000000002, independent_yield_percent=1.65, cumulative_yield_percent=2.56),
#  FPY(name='Te-131', element_name='Tellurium', Z=52, A=131, half_life=1500.0, independent_yield_percent=0.097, cumulative_yield_percent=2.55),
#  FPY(name='Sb-133', element_name='Antimony', Z=51, A=133, half_life=150.0, independent_yield_percent=2.26, cumulative_yield_percent=2.4),
#  FPY(name='Nd-147', element_name='Neodymium', Z=60, A=147, half_life=948672.0000000002, independent_yield_percent=6.72e-05, cumulative_yield_percent=2.25),
#  FPY(name='Pm-147', element_name='Promethium', Z=61, A=147, half_life=82731542.4, independent_yield_percent=2.49e-09, cumulative_yield_percent=2.25),
#  FPY(name='Sm-147', element_name='Samarium', Z=62, A=147, half_life=3.342816e+18, independent_yield_percent=0.0, cumulative_yield_percent=2.25),
#  FPY(name='Pr-147', element_name='Praseodymium', Z=59, A=147, half_life=804.0, independent_yield_percent=0.36, cumulative_yield_percent=2.25),
#  FPY(name='Y-93m', element_name='Yttrium', Z=39, A=93, half_life=0.8200000000000001, independent_yield_percent=0.0543, cumulative_yield_percent=2.21),
#  FPY(name='Nb-99m', element_name='Niobium', Z=41, A=99, half_life=150.0, independent_yield_percent=0.407, cumulative_yield_percent=2.1),
#  FPY(name='Y-99', element_name='Yttrium', Z=39, A=99, half_life=1.47, independent_yield_percent=1.95, cumulative_yield_percent=2.08),
#  FPY(name='Zr-102', element_name='Zirconium', Z=40, A=102, half_life=2.9, independent_yield_percent=1.78, cumulative_yield_percent=2.05),
#  FPY(name='Br-87', element_name='Bromine', Z=35, A=87, half_life=55.65, independent_yield_percent=1.27, cumulative_yield_percent=2.03),
#  FPY(name='Y-96m', element_name='Yttrium', Z=39, A=96, half_life=9.6, independent_yield_percent=2.02, cumulative_yield_percent=2.02),
#  FPY(name='Ba-145', element_name='Barium', Z=56, A=145, half_life=4.31, independent_yield_percent=1.87, cumulative_yield_percent=1.93),
#  FPY(name='Y-98', element_name='Yttrium', Z=39, A=98, half_life=0.548, independent_yield_percent=1.11, cumulative_yield_percent=1.92),
#  FPY(name='Nb-103', element_name='Niobium', Z=41, A=103, half_life=1.5, independent_yield_percent=1.41, cumulative_yield_percent=1.91),
#  FPY(name='Ce-147', element_name='Cerium', Z=58, A=147, half_life=56.4, independent_yield_percent=0.998, cumulative_yield_percent=1.89),
#  FPY(name='Tc-104', element_name='Technetium', Z=43, A=104, half_life=1098.0, independent_yield_percent=0.0926, cumulative_yield_percent=1.88),
#  FPY(name='Te-130', element_name='Tellurium', Z=52, A=130, half_life=0.0, independent_yield_percent=0.0579, cumulative_yield_percent=1.81),
#  FPY(name='Mo-104', element_name='Molybdenum', Z=42, A=104, half_life=60.0, independent_yield_percent=1.13, cumulative_yield_percent=1.79),
#  FPY(name='Br-88', element_name='Bromine', Z=35, A=88, half_life=16.29, independent_yield_percent=1.39, cumulative_yield_percent=1.78),
#  FPY(name='Sr-97', element_name='Strontium', Z=38, A=97, half_life=0.429, independent_yield_percent=1.72, cumulative_yield_percent=1.75),
#  FPY(name='Kr-92', element_name='Krypton', Z=36, A=92, half_life=1.84, independent_yield_percent=1.66, cumulative_yield_percent=1.67),
#  FPY(name='La-146', element_name='Lanthanum', Z=57, A=146, half_life=6.27, independent_yield_percent=0.745, cumulative_yield_percent=1.67),
#  FPY(name='Rb-94', element_name='Rubidium', Z=37, A=94, half_life=2.702, independent_yield_percent=1.57, cumulative_yield_percent=1.65),
#  FPY(name='Pr-148', element_name='Praseodymium', Z=59, A=148, half_life=137.4, independent_yield_percent=0.0389, cumulative_yield_percent=1.63),
#  FPY(name='Sb-132', element_name='Antimony', Z=51, A=132, half_life=167.4, independent_yield_percent=1.3, cumulative_yield_percent=1.6),
#  FPY(name='Br-86', element_name='Bromine', Z=35, A=86, half_life=55.0, independent_yield_percent=0.23, cumulative_yield_percent=1.59),
#  FPY(name='Ce-148', element_name='Cerium', Z=58, A=148, half_life=56.0, independent_yield_percent=1.24, cumulative_yield_percent=1.59),
#  FPY(name='I-138', element_name='Iodine', Z=53, A=138, half_life=6.23, independent_yield_percent=1.42, cumulative_yield_percent=1.49),
#  FPY(name='Cs-143', element_name='Cesium', Z=55, A=143, half_life=1.791, independent_yield_percent=1.4, cumulative_yield_percent=1.45),
#  FPY(name='Se-86', element_name='Selenium', Z=34, A=86, half_life=14.3, independent_yield_percent=0.836, cumulative_yield_percent=1.37),
#  FPY(name='Te-136', element_name='Tellurium', Z=52, A=136, half_life=17.5, independent_yield_percent=1.32, cumulative_yield_percent=1.34),
#  FPY(name='Kr-85m', element_name='Krypton', Z=36, A=85, half_life=16128.0, independent_yield_percent=0.00589, cumulative_yield_percent=1.29),
#  FPY(name='Br-85', element_name='Bromine', Z=35, A=85, half_life=174.0, independent_yield_percent=0.235, cumulative_yield_percent=1.28),
#  FPY(name='I-136m', element_name='Iodine', Z=53, A=136, half_life=46.9, independent_yield_percent=1.25, cumulative_yield_percent=1.26),
#  FPY(name='Xe-141', element_name='Xenon', Z=54, A=141, half_life=1.73, independent_yield_percent=1.22, cumulative_yield_percent=1.25),
#  FPY(name='Rb-90m', element_name='Rubidium', Z=37, A=90, half_life=258.0, independent_yield_percent=0.707, cumulative_yield_percent=1.24),
#  FPY(name='Sb-132m', element_name='Antimony', Z=51, A=132, half_life=246.0, independent_yield_percent=0.863, cumulative_yield_percent=1.16),
#  FPY(name='Y-98m', element_name='Yttrium', Z=39, A=98, half_life=2.0, independent_yield_percent=1.11, cumulative_yield_percent=1.11),
#  FPY(name='Xe-135m', element_name='Xenon', Z=54, A=135, half_life=917.4, independent_yield_percent=0.178, cumulative_yield_percent=1.1),
#  FPY(name='Br-89', element_name='Bromine', Z=35, A=89, half_life=4.4, independent_yield_percent=1.04, cumulative_yield_percent=1.09),
#  FPY(name='Pm-149', element_name='Promethium', Z=61, A=149, half_life=191087.99999999997, independent_yield_percent=3.87e-06, cumulative_yield_percent=1.08),
#  FPY(name='Nd-149', element_name='Neodymium', Z=60, A=149, half_life=6220.799999999999, independent_yield_percent=0.00681, cumulative_yield_percent=1.08),
#  FPY(name='Pr-149', element_name='Praseodymium', Z=59, A=149, half_life=135.6, independent_yield_percent=0.297, cumulative_yield_percent=1.07),
#  FPY(name='Br-84', element_name='Bromine', Z=35, A=84, half_life=1905.6000000000001, independent_yield_percent=0.0186, cumulative_yield_percent=0.985),
#  FPY(name='Sb-130m', element_name='Antimony', Z=51, A=130, half_life=378.0, independent_yield_percent=0.357, cumulative_yield_percent=0.967),
#  FPY(name='Se-84', element_name='Selenium', Z=34, A=84, half_life=195.6, independent_yield_percent=0.631, cumulative_yield_percent=0.966),
#  FPY(name='Tc-105', element_name='Technetium', Z=43, A=105, half_life=456.0, independent_yield_percent=0.0485, cumulative_yield_percent=0.964),
#  FPY(name='Ru-105', element_name='Ruthenium', Z=44, A=105, half_life=15984.000000000002, independent_yield_percent=1.11e-07, cumulative_yield_percent=0.964),
#  FPY(name='Rh-105', element_name='Rhodium', Z=45, A=105, half_life=127296.0, independent_yield_percent=0.0, cumulative_yield_percent=0.964),
#  FPY(name='Ba-146', element_name='Barium', Z=56, A=146, half_life=2.22, independent_yield_percent=0.914, cumulative_yield_percent=0.92),
#  FPY(name='Mo-105', element_name='Molybdenum', Z=42, A=105, half_life=35.6, independent_yield_percent=0.668, cumulative_yield_percent=0.916),
#  FPY(name='La-147', element_name='Lanthanum', Z=57, A=147, half_life=4.06, independent_yield_percent=0.643, cumulative_yield_percent=0.889),
#  FPY(name='Sr-98', element_name='Strontium', Z=38, A=98, half_life=0.653, independent_yield_percent=0.808, cumulative_yield_percent=0.812),
#  FPY(name='Nb-102m', element_name='Niobium', Z=41, A=102, half_life=1.3, independent_yield_percent=0.789, cumulative_yield_percent=0.789),
#  FPY(name='Sb-130', element_name='Antimony', Z=51, A=130, half_life=2370.0, independent_yield_percent=0.215, cumulative_yield_percent=0.785),
#  FPY(name='Ce-149', element_name='Cerium', Z=58, A=149, half_life=5.3, independent_yield_percent=0.698, cumulative_yield_percent=0.778),
#  FPY(name='I-139', element_name='Iodine', Z=53, A=139, half_life=2.28, independent_yield_percent=0.771, cumulative_yield_percent=0.778),
#  FPY(name='Rb-95', element_name='Rubidium', Z=37, A=95, half_life=0.3777, independent_yield_percent=0.764, cumulative_yield_percent=0.77),
#  FPY(name='Se-87', element_name='Selenium', Z=34, A=87, half_life=5.5, independent_yield_percent=0.731, cumulative_yield_percent=0.76),
#  FPY(name='La-146m', element_name='Lanthanum', Z=57, A=146, half_life=10.0, independent_yield_percent=0.745, cumulative_yield_percent=0.745),
#  FPY(name='Nd-150', element_name='Neodymium', Z=60, A=150, half_life=2.491344e+26, independent_yield_percent=0.0327, cumulative_yield_percent=0.653),
#  FPY(name='Ge-86', element_name='Germanium', Z=32, A=86, half_life=0.095, independent_yield_percent=0.629, cumulative_yield_percent=0.629),
#  FPY(name='Pr-150', element_name='Praseodymium', Z=59, A=150, half_life=6.19, independent_yield_percent=0.218, cumulative_yield_percent=0.621),
#  FPY(name='Sn-130', element_name='Tin', Z=50, A=130, half_life=223.20000000000002, independent_yield_percent=0.542, cumulative_yield_percent=0.611),
#  FPY(name='Y-100', element_name='Yttrium', Z=39, A=100, half_life=0.735, independent_yield_percent=0.567, cumulative_yield_percent=0.61),
#  FPY(name='Sn-132', element_name='Tin', Z=50, A=132, half_life=39.7, independent_yield_percent=0.592, cumulative_yield_percent=0.598),
#  FPY(name='Sn-130m', element_name='Tin', Z=50, A=130, half_life=102.0, independent_yield_percent=0.542, cumulative_yield_percent=0.57),
#  FPY(name='Br-90', element_name='Bromine', Z=35, A=90, half_life=1.92, independent_yield_percent=0.553, cumulative_yield_percent=0.564),
#  FPY(name='Se-85', element_name='Selenium', Z=34, A=85, half_life=31.7, independent_yield_percent=0.447, cumulative_yield_percent=0.556),
#  FPY(name='As-86', element_name='Arsenic', Z=33, A=86, half_life=0.9450000000000001, independent_yield_percent=0.0199, cumulative_yield_percent=0.553),
#  FPY(name='I-129', element_name='Iodine', Z=53, A=129, half_life=495115200000000.0, independent_yield_percent=0.0, cumulative_yield_percent=0.543),
#  FPY(name='Sb-129', element_name='Antimony', Z=51, A=129, half_life=15840.0, independent_yield_percent=0.0641, cumulative_yield_percent=0.543),
#  FPY(name='Kr-83m', element_name='Krypton', Z=36, A=83, half_life=6588.000000000001, independent_yield_percent=1.55e-06, cumulative_yield_percent=0.536),
#  FPY(name='Br-83', element_name='Bromine', Z=35, A=83, half_life=8640.0, independent_yield_percent=0.0195, cumulative_yield_percent=0.536),
#  FPY(name='Te-129', element_name='Tellurium', Z=52, A=129, half_life=4176.0, independent_yield_percent=5.73e-06, cumulative_yield_percent=0.511),
#  FPY(name='Zr-103', element_name='Zirconium', Z=40, A=103, half_life=1.3, independent_yield_percent=0.499, cumulative_yield_percent=0.501),
#  FPY(name='Se-85m', element_name='Selenium', Z=34, A=85, half_life=0.0, independent_yield_percent=0.447, cumulative_yield_percent=0.494),
#  FPY(name='Kr-93', element_name='Krypton', Z=36, A=93, half_life=1.286, independent_yield_percent=0.486, cumulative_yield_percent=0.489),
#  FPY(name='Sn-131', element_name='Tin', Z=50, A=131, half_life=56.0, independent_yield_percent=0.441, cumulative_yield_percent=0.464),
#  FPY(name='Te-137', element_name='Tellurium', Z=52, A=137, half_life=2.49, independent_yield_percent=0.392, cumulative_yield_percent=0.453),
#  FPY(name='Sn-131m', element_name='Tin', Z=50, A=131, half_life=58.4, independent_yield_percent=0.441, cumulative_yield_percent=0.442),
#  FPY(name='Xe-142', element_name='Xenon', Z=54, A=142, half_life=1.23, independent_yield_percent=0.434, cumulative_yield_percent=0.439),
#  FPY(name='Cs-144', element_name='Cesium', Z=55, A=144, half_life=0.994, independent_yield_percent=0.418, cumulative_yield_percent=0.423),
#  FPY(name='Pm-151', element_name='Promethium', Z=61, A=151, half_life=102240.0, independent_yield_percent=0.000642, cumulative_yield_percent=0.419),
#  FPY(name='Sm-151', element_name='Samarium', Z=62, A=151, half_life=2838240000.0, independent_yield_percent=4.75e-07, cumulative_yield_percent=0.419),
#  FPY(name='Eu-151', element_name='Europium', Z=63, A=151, half_life=0.0, independent_yield_percent=2.49e-10, cumulative_yield_percent=0.419),
#  FPY(name='Nd-151', element_name='Neodymium', Z=60, A=151, half_life=746.4, independent_yield_percent=0.0795, cumulative_yield_percent=0.418),
#  FPY(name='Te-131m', element_name='Tellurium', Z=52, A=131, half_life=119664.0, independent_yield_percent=0.233, cumulative_yield_percent=0.412),
#  FPY(name='Ce-150', element_name='Cerium', Z=58, A=150, half_life=4.0, independent_yield_percent=0.392, cumulative_yield_percent=0.402),
#  FPY(name='Ru-106', element_name='Ruthenium', Z=44, A=106, half_life=32123520.0, independent_yield_percent=9.07e-07, cumulative_yield_percent=0.402),
#  FPY(name='Rh-106', element_name='Rhodium', Z=45, A=106, half_life=30.07, independent_yield_percent=0.0, cumulative_yield_percent=0.402),
#  FPY(name='Tc-106', element_name='Technetium', Z=43, A=106, half_life=35.6, independent_yield_percent=0.0268, cumulative_yield_percent=0.402),
#  FPY(name='Se-88', element_name='Selenium', Z=34, A=88, half_life=1.53, independent_yield_percent=0.268, cumulative_yield_percent=0.392),
#  FPY(name='Mo-106', element_name='Molybdenum', Z=42, A=106, half_life=8.73, independent_yield_percent=0.359, cumulative_yield_percent=0.375),
#  FPY(name='Sb-134', element_name='Antimony', Z=51, A=134, half_life=0.78, independent_yield_percent=0.358, cumulative_yield_percent=0.373),
#  FPY(name='Nb-104', element_name='Niobium', Z=41, A=104, half_life=4.9, independent_yield_percent=0.285, cumulative_yield_percent=0.37),
#  FPY(name='I-134m', element_name='Iodine', Z=53, A=134, half_life=211.2, independent_yield_percent=0.364, cumulative_yield_percent=0.364),
#  FPY(name='La-148', element_name='Lanthanum', Z=57, A=148, half_life=1.26, independent_yield_percent=0.336, cumulative_yield_percent=0.358),
#  FPY(name='Sb-134m', element_name='Antimony', Z=51, A=134, half_life=10.07, independent_yield_percent=0.358, cumulative_yield_percent=0.358),
#  FPY(name='Te-128', element_name='Tellurium', Z=52, A=128, half_life=2.775168e+26, independent_yield_percent=0.000172, cumulative_yield_percent=0.349),
#  FPY(name='As-83', element_name='Arsenic', Z=33, A=83, half_life=13.4, independent_yield_percent=0.291, cumulative_yield_percent=0.34),
#  FPY(name='Pr-151', element_name='Praseodymium', Z=59, A=151, half_life=18.9, independent_yield_percent=0.239, cumulative_yield_percent=0.339),
#  FPY(name='Sb-128m', element_name='Antimony', Z=51, A=128, half_life=624.0, independent_yield_percent=0.00637, cumulative_yield_percent=0.338),
#  FPY(name='Sn-128', element_name='Tin', Z=50, A=128, half_life=3544.2, independent_yield_percent=0.15, cumulative_yield_percent=0.332),
#  FPY(name='Nb-104m', element_name='Niobium', Z=41, A=104, half_life=0.9400000000000001, independent_yield_percent=0.285, cumulative_yield_percent=0.285),
#  FPY(name='Kr-85', element_name='Krypton', Z=36, A=85, half_life=339201215.99999994, independent_yield_percent=0.0255, cumulative_yield_percent=0.283),
#  FPY(name='Y-101', element_name='Yttrium', Z=39, A=101, half_life=0.45, independent_yield_percent=0.278, cumulative_yield_percent=0.282),
#  FPY(name='Sn-129', element_name='Tin', Z=50, A=129, half_life=133.8, independent_yield_percent=0.23, cumulative_yield_percent=0.282),
#  FPY(name='Y-102', element_name='Yttrium', Z=39, A=102, half_life=0.36, independent_yield_percent=0.268, cumulative_yield_percent=0.268),
#  FPY(name='Se-83', element_name='Selenium', Z=34, A=83, half_life=1338.0, independent_yield_percent=0.143, cumulative_yield_percent=0.265),
#  FPY(name='Pm-152', element_name='Promethium', Z=61, A=152, half_life=247.20000000000002, independent_yield_percent=0.000928, cumulative_yield_percent=0.265),
#  FPY(name='Nd-152', element_name='Neodymium', Z=60, A=152, half_life=684.0, independent_yield_percent=0.141, cumulative_yield_percent=0.264),
#  FPY(name='Rh-105m', element_name='Rhodium', Z=45, A=105, half_life=40.0, independent_yield_percent=0.0, cumulative_yield_percent=0.26),
#  FPY(name='As-82', element_name='Arsenic', Z=33, A=82, half_life=19.1, independent_yield_percent=0.129, cumulative_yield_percent=0.26),
#  FPY(name='Nb-105', element_name='Niobium', Z=41, A=105, half_life=2.95, independent_yield_percent=0.139, cumulative_yield_percent=0.253),
#  FPY(name='Se-83m', element_name='Selenium', Z=34, A=83, half_life=70.1, independent_yield_percent=0.0335, cumulative_yield_percent=0.251),
#  FPY(name='Ba-147', element_name='Barium', Z=56, A=147, half_life=0.894, independent_yield_percent=0.244, cumulative_yield_percent=0.246),
#  FPY(name='Br-86m', element_name='Bromine', Z=35, A=86, half_life=0.0, independent_yield_percent=0.23, cumulative_yield_percent=0.231),
#  FPY(name='Br-91', element_name='Bromine', Z=35, A=91, half_life=0.541, independent_yield_percent=0.224, cumulative_yield_percent=0.224),
#  FPY(name='Tc-102', element_name='Technetium', Z=43, A=102, half_life=5.28, independent_yield_percent=0.00955, cumulative_yield_percent=0.224),
#  FPY(name='Cs-138m', element_name='Cesium', Z=55, A=138, half_life=174.60000000000002, independent_yield_percent=0.223, cumulative_yield_percent=0.223),
#  FPY(name='As-85', element_name='Arsenic', Z=33, A=85, half_life=2.021, independent_yield_percent=0.121, cumulative_yield_percent=0.219),
#  FPY(name='Rb-96', element_name='Rubidium', Z=37, A=96, half_life=0.203, independent_yield_percent=0.168, cumulative_yield_percent=0.206),
#  FPY(name='Se-81', element_name='Selenium', Z=34, A=81, half_life=1107.0, independent_yield_percent=0.00104, cumulative_yield_percent=0.204),
#  FPY(name='Sn-129m', element_name='Tin', Z=50, A=129, half_life=414.0, independent_yield_percent=0.196, cumulative_yield_percent=0.197),
#  FPY(name='As-81', element_name='Arsenic', Z=33, A=81, half_life=33.3, independent_yield_percent=0.0609, cumulative_yield_percent=0.196),
#  FPY(name='Xe-133m', element_name='Xenon', Z=54, A=133, half_life=189216.0, independent_yield_percent=0.00189, cumulative_yield_percent=0.195),
#  FPY(name='Sm-153', element_name='Samarium', Z=62, A=153, half_life=167400.0, independent_yield_percent=8.01e-05, cumulative_yield_percent=0.158),
#  FPY(name='Pm-153', element_name='Promethium', Z=61, A=153, half_life=315.0, independent_yield_percent=0.0088, cumulative_yield_percent=0.158),
#  FPY(name='Sb-127', element_name='Antimony', Z=51, A=127, half_life=332640.0, independent_yield_percent=0.00709, cumulative_yield_percent=0.157),
#  FPY(name='Te-127', element_name='Tellurium', Z=52, A=127, half_life=33660.0, independent_yield_percent=9.92e-09, cumulative_yield_percent=0.156),
#  FPY(name='I-140', element_name='Iodine', Z=53, A=140, half_life=0.86, independent_yield_percent=0.137, cumulative_yield_percent=0.154),
#  FPY(name='Sn-128m', element_name='Tin', Z=50, A=128, half_life=6.5, independent_yield_percent=0.15, cumulative_yield_percent=0.15),
#  FPY(name='Nd-153', element_name='Neodymium', Z=60, A=153, half_life=31.6, independent_yield_percent=0.111, cumulative_yield_percent=0.149),
#  FPY(name='Ru-107', element_name='Ruthenium', Z=44, A=107, half_life=225.0, independent_yield_percent=4.94e-06, cumulative_yield_percent=0.146),
#  FPY(name='Rh-107', element_name='Rhodium', Z=45, A=107, half_life=1302.0, independent_yield_percent=0.0, cumulative_yield_percent=0.146),
#  FPY(name='Pd-107', element_name='Palladium', Z=46, A=107, half_life=204984000000000.0, independent_yield_percent=0.0, cumulative_yield_percent=0.146),
#  FPY(name='Tc-107', element_name='Technetium', Z=43, A=107, half_life=21.2, independent_yield_percent=0.0224, cumulative_yield_percent=0.146),
#  FPY(name='Sb-135', element_name='Antimony', Z=51, A=135, half_life=1.679, independent_yield_percent=0.145, cumulative_yield_percent=0.146),
#  FPY(name='Sn-133', element_name='Tin', Z=50, A=133, half_life=1.46, independent_yield_percent=0.138, cumulative_yield_percent=0.138),
#  FPY(name='Ge-81', element_name='Germanium', Z=32, A=81, half_life=7.6, independent_yield_percent=0.126, cumulative_yield_percent=0.135),
#  FPY(name='Sr-99', element_name='Strontium', Z=38, A=99, half_life=0.27, independent_yield_percent=0.133, cumulative_yield_percent=0.133),
#  FPY(name='Ge-82', element_name='Germanium', Z=32, A=82, half_life=4.55, independent_yield_percent=0.126, cumulative_yield_percent=0.132),
#  FPY(name='Se-80', element_name='Selenium', Z=34, A=80, half_life=0.0, independent_yield_percent=0.000489, cumulative_yield_percent=0.129),
#  FPY(name='As-80', element_name='Arsenic', Z=33, A=80, half_life=15.2, independent_yield_percent=0.0137, cumulative_yield_percent=0.128),
#  FPY(name='As-84', element_name='Arsenic', Z=33, A=84, half_life=4.2, independent_yield_percent=0.0987, cumulative_yield_percent=0.128),
#  FPY(name='As-88', element_name='Arsenic', Z=33, A=88, half_life=0.112, independent_yield_percent=0.124, cumulative_yield_percent=0.124),
#  FPY(name='Mo-107', element_name='Molybdenum', Z=42, A=107, half_life=3.5, independent_yield_percent=0.121, cumulative_yield_percent=0.124),
#  FPY(name='Pr-152', element_name='Praseodymium', Z=59, A=152, half_life=3.63, independent_yield_percent=0.103, cumulative_yield_percent=0.123),
#  FPY(name='Sn-127', element_name='Tin', Z=50, A=127, half_life=7560.0, independent_yield_percent=0.0867, cumulative_yield_percent=0.119),
#  FPY(name='Zr-105', element_name='Zirconium', Z=40, A=105, half_life=0.6, independent_yield_percent=0.116, cumulative_yield_percent=0.116),
#  FPY(name='Ge-80', element_name='Germanium', Z=32, A=80, half_life=29.5, independent_yield_percent=0.102, cumulative_yield_percent=0.115),
#  FPY(name='Ce-151', element_name='Cerium', Z=58, A=151, half_life=1.76, independent_yield_percent=0.099, cumulative_yield_percent=0.1),
#  FPY(name='As-84m', element_name='Arsenic', Z=33, A=84, half_life=0.0, independent_yield_percent=0.0987, cumulative_yield_percent=0.0987),
#  FPY(name='In-130', element_name='Indium', Z=49, A=130, half_life=0.29, independent_yield_percent=0.00314, cumulative_yield_percent=0.0972),
#  FPY(name='Te-129m', element_name='Tellurium', Z=52, A=129, half_life=2903040.0, independent_yield_percent=1.4e-05, cumulative_yield_percent=0.0902),
#  FPY(name='Cd-130', element_name='Cadmium', Z=48, A=130, half_life=0.162, independent_yield_percent=0.0878, cumulative_yield_percent=0.0878),
#  FPY(name='Kr-94', element_name='Krypton', Z=36, A=94, half_life=0.212, independent_yield_percent=0.0868, cumulative_yield_percent=0.087),
#  FPY(name='Zr-104', element_name='Zirconium', Z=40, A=104, half_life=1.2, independent_yield_percent=0.0828, cumulative_yield_percent=0.0834),
#  FPY(name='I-133m', element_name='Iodine', Z=53, A=133, half_life=9.0, independent_yield_percent=0.0825, cumulative_yield_percent=0.0825),
#  FPY(name='La-149', element_name='Lanthanum', Z=57, A=149, half_life=1.05, independent_yield_percent=0.0799, cumulative_yield_percent=0.0809),
#  FPY(name='Cs-145', element_name='Cesium', Z=55, A=145, half_life=0.587, independent_yield_percent=0.0756, cumulative_yield_percent=0.0757),
#  FPY(name='Sb-137', element_name='Antimony', Z=51, A=137, half_life=0.45, independent_yield_percent=0.0743, cumulative_yield_percent=0.0743),
#  FPY(name='Pm-154', element_name='Promethium', Z=61, A=154, half_life=103.8, independent_yield_percent=0.00541, cumulative_yield_percent=0.0685),
#  FPY(name='Te-138', element_name='Tellurium', Z=52, A=138, half_life=1.4, independent_yield_percent=0.0662, cumulative_yield_percent=0.0662),
#  FPY(name='Nb-95m', element_name='Niobium', Z=41, A=95, half_life=311904.0, independent_yield_percent=2.48e-05, cumulative_yield_percent=0.0651),
#  FPY(name='Nd-154', element_name='Neodymium', Z=60, A=154, half_life=25.9, independent_yield_percent=0.058, cumulative_yield_percent=0.0631),
#  FPY(name='Sb-126m', element_name='Antimony', Z=51, A=126, half_life=1149.0, independent_yield_percent=0.000859, cumulative_yield_percent=0.0579),
#  FPY(name='Sn-126', element_name='Tin', Z=50, A=126, half_life=7253280000000.0, independent_yield_percent=0.0445, cumulative_yield_percent=0.0561),
#  FPY(name='Ru-108', element_name='Ruthenium', Z=44, A=108, half_life=273.0, independent_yield_percent=1.67e-05, cumulative_yield_percent=0.0541),
#  FPY(name='Rh-108', element_name='Rhodium', Z=45, A=108, half_life=16.8, independent_yield_percent=0.0, cumulative_yield_percent=0.0541),
#  FPY(name='Tc-108', element_name='Technetium', Z=43, A=108, half_life=5.17, independent_yield_percent=0.0238, cumulative_yield_percent=0.0541),
#  FPY(name='As-87', element_name='Arsenic', Z=33, A=87, half_life=0.56, independent_yield_percent=0.0505, cumulative_yield_percent=0.0527),
#  FPY(name='Se-89', element_name='Selenium', Z=34, A=89, half_life=0.41000000000000003, independent_yield_percent=0.0485, cumulative_yield_percent=0.0487),
#  FPY(name='Ge-83', element_name='Germanium', Z=32, A=83, half_life=1.85, independent_yield_percent=0.0479, cumulative_yield_percent=0.048),
#  FPY(name='In-127', element_name='Indium', Z=49, A=127, half_life=1.09, independent_yield_percent=0.0412, cumulative_yield_percent=0.0452),
#  FPY(name='Se-79', element_name='Selenium', Z=34, A=79, half_life=9303120000000.0, independent_yield_percent=1.1e-05, cumulative_yield_percent=0.0447),
#  FPY(name='Se-79m', element_name='Selenium', Z=34, A=79, half_life=235.2, independent_yield_percent=1.65e-06, cumulative_yield_percent=0.0447),
#  FPY(name='As-79', element_name='Arsenic', Z=33, A=79, half_life=540.6, independent_yield_percent=0.00266, cumulative_yield_percent=0.0447),
#  FPY(name='Sr-100', element_name='Strontium', Z=38, A=100, half_life=0.202, independent_yield_percent=0.00815, cumulative_yield_percent=0.0429),
#  FPY(name='I-141', element_name='Iodine', Z=53, A=141, half_life=0.43, independent_yield_percent=0.0407, cumulative_yield_percent=0.0407),
#  FPY(name='Xe-131m', element_name='Xenon', Z=54, A=131, half_life=1022976.0, independent_yield_percent=3.48e-07, cumulative_yield_percent=0.0405),
#  FPY(name='Pr-148m', element_name='Praseodymium', Z=59, A=148, half_life=120.6, independent_yield_percent=0.0389, cumulative_yield_percent=0.0389),
#  FPY(name='Nb-98m', element_name='Niobium', Z=41, A=98, half_life=3078.0, independent_yield_percent=0.0385, cumulative_yield_percent=0.0385),
#  FPY(name='Sb-126n', element_name='Antimony', Z=51, A=126, half_life=11.0, independent_yield_percent=0.000859, cumulative_yield_percent=0.0385),
#  FPY(name='Pr-153', element_name='Praseodymium', Z=59, A=153, half_life=4.28, independent_yield_percent=0.0367, cumulative_yield_percent=0.0385),
#  FPY(name='Rb-97', element_name='Rubidium', Z=37, A=97, half_life=0.1691, independent_yield_percent=0.0379, cumulative_yield_percent=0.038),
#  FPY(name='Kr-96', element_name='Krypton', Z=36, A=96, half_life=0.08, independent_yield_percent=0.0378, cumulative_yield_percent=0.0378),
#  FPY(name='Rb-100', element_name='Rubidium', Z=37, A=100, half_life=0.051000000000000004, independent_yield_percent=0.0348, cumulative_yield_percent=0.0348),
#  FPY(name='Sb-125', element_name='Antimony', Z=51, A=125, half_life=86993948.16, independent_yield_percent=2.74e-05, cumulative_yield_percent=0.034),
#  FPY(name='Eu-155', element_name='Europium', Z=63, A=155, half_life=149890607.99999997, independent_yield_percent=2.63e-06, cumulative_yield_percent=0.0321),
#  FPY(name='Sm-155', element_name='Samarium', Z=62, A=155, half_life=1338.0, independent_yield_percent=0.00131, cumulative_yield_percent=0.0321),
#  FPY(name='Xe-134m', element_name='Xenon', Z=54, A=134, half_life=0.29, independent_yield_percent=0.0246, cumulative_yield_percent=0.0319),
#  FPY(name='Rh-109', element_name='Rhodium', Z=45, A=109, half_life=80.0, independent_yield_percent=2.06e-06, cumulative_yield_percent=0.0312),
#  FPY(name='Pd-109', element_name='Palladium', Z=46, A=109, half_life=49324.32, independent_yield_percent=2.94e-10, cumulative_yield_percent=0.0312),
#  FPY(name='Ag-109m', element_name='Silver', Z=47, A=109, half_life=39.6, independent_yield_percent=0.0, cumulative_yield_percent=0.0312),
#  FPY(name='Pm-155', element_name='Promethium', Z=61, A=155, half_life=41.5, independent_yield_percent=0.0126, cumulative_yield_percent=0.0308),
#  FPY(name='Sn-127m', element_name='Tin', Z=50, A=127, half_life=247.79999999999998, independent_yield_percent=0.00792, cumulative_yield_percent=0.0304),
#  FPY(name='Ru-109', element_name='Ruthenium', Z=44, A=109, half_life=34.5, independent_yield_percent=0.000856, cumulative_yield_percent=0.0304),
#  FPY(name='Mo-108', element_name='Molybdenum', Z=42, A=108, half_life=1.09, independent_yield_percent=0.0302, cumulative_yield_percent=0.0303),
#  FPY(name='Ge-84', element_name='Germanium', Z=32, A=84, half_life=0.9540000000000001, independent_yield_percent=0.019, cumulative_yield_percent=0.0301),
#  FPY(name='Ge-79', element_name='Germanium', Z=32, A=79, half_life=18.98, independent_yield_percent=0.0116, cumulative_yield_percent=0.03),
#  FPY(name='Tc-109', element_name='Technetium', Z=43, A=109, half_life=0.86, independent_yield_percent=0.0134, cumulative_yield_percent=0.0294),
#  FPY(name='In-129', element_name='Indium', Z=49, A=129, half_life=0.61, independent_yield_percent=0.0275, cumulative_yield_percent=0.0275),
#  FPY(name='Pr-144m', element_name='Praseodymium', Z=59, A=144, half_life=432.0, independent_yield_percent=1.28e-05, cumulative_yield_percent=0.0275),
#  FPY(name='As-82m', element_name='Arsenic', Z=33, A=82, half_life=13.6, independent_yield_percent=0.0271, cumulative_yield_percent=0.0271),
#  FPY(name='Br-92', element_name='Bromine', Z=35, A=92, half_life=0.343, independent_yield_percent=0.0268, cumulative_yield_percent=0.0268),
#  FPY(name='Xe-143', element_name='Xenon', Z=54, A=143, half_life=0.3, independent_yield_percent=0.0265, cumulative_yield_percent=0.0265),
#  FPY(name='Xe-143m', element_name='Xenon', Z=54, A=143, half_life=0.0, independent_yield_percent=0.0265, cumulative_yield_percent=0.0265),
#  FPY(name='Rh-110', element_name='Rhodium', Z=45, A=110, half_life=3.2, independent_yield_percent=5.65e-05, cumulative_yield_percent=0.0254),
#  FPY(name='In-129m', element_name='Indium', Z=49, A=129, half_life=1.23, independent_yield_percent=0.0253, cumulative_yield_percent=0.0253),
#  FPY(name='Ru-110', element_name='Ruthenium', Z=44, A=110, half_life=11.6, independent_yield_percent=0.00989, cumulative_yield_percent=0.0253),
#  FPY(name='Te-127m', element_name='Tellurium', Z=52, A=127, half_life=9417600.0, independent_yield_percent=2.43e-08, cumulative_yield_percent=0.0251),
#  FPY(name='In-131', element_name='Indium', Z=49, A=131, half_life=0.28, independent_yield_percent=0.00556, cumulative_yield_percent=0.0249),
#  FPY(name='Sb-128', element_name='Antimony', Z=51, A=128, half_life=32436.0, independent_yield_percent=0.0107, cumulative_yield_percent=0.0228),
#  FPY(name='Ba-148', element_name='Barium', Z=56, A=148, half_life=0.612, independent_yield_percent=0.0222, cumulative_yield_percent=0.0222),
#  FPY(name='As-78', element_name='Arsenic', Z=33, A=78, half_life=5442.0, independent_yield_percent=0.00013, cumulative_yield_percent=0.021),
#  FPY(name='Ge-78', element_name='Germanium', Z=32, A=78, half_life=5280.0, independent_yield_percent=0.00694, cumulative_yield_percent=0.0208),
#  FPY(name='Ce-152', element_name='Cerium', Z=58, A=152, half_life=1.4, independent_yield_percent=0.0205, cumulative_yield_percent=0.0206),
#  FPY(name='Ga-79', element_name='Gallium', Z=31, A=79, half_life=2.847, independent_yield_percent=0.0171, cumulative_yield_percent=0.0187),
#  FPY(name='Nd-155', element_name='Neodymium', Z=60, A=155, half_life=8.9, independent_yield_percent=0.0175, cumulative_yield_percent=0.0182),
#  FPY(name='Sn-125m', element_name='Tin', Z=50, A=125, half_life=571.1999999999999, independent_yield_percent=0.0105, cumulative_yield_percent=0.018),
#  FPY(name='Sn-134', element_name='Tin', Z=50, A=134, half_life=1.05, independent_yield_percent=0.0177, cumulative_yield_percent=0.0177),
#  FPY(name='Rh-111', element_name='Rhodium', Z=45, A=111, half_life=11.0, independent_yield_percent=0.00088, cumulative_yield_percent=0.0174),
#  FPY(name='Pd-111', element_name='Palladium', Z=46, A=111, half_life=1404.0, independent_yield_percent=2.54e-06, cumulative_yield_percent=0.0174),
# ...
#  FPY(name='Tb-172', element_name='Terbium', Z=65, A=172, half_life=0.0, independent_yield_percent=1.05e-12, cumulative_yield_percent=1.05e-12),
#  FPY(name='Rh-124', element_name='Rhodium', Z=45, A=124, half_life=0.0, independent_yield_percent=1.04e-12, cumulative_yield_percent=1.04e-12),
#  FPY(name='Ba-133', element_name='Barium', Z=56, A=133, half_life=331862400.0, independent_yield_percent=1.04e-12, cumulative_yield_percent=1.04e-12),
#  FPY(name='Ag-110', element_name='Silver', Z=47, A=110, half_life=24.6, independent_yield_percent=0.0, cumulative_yield_percent=1.01e-12),
#  FPY(name='Cu-83', element_name='Copper', Z=29, A=83, half_life=0.0, independent_yield_percent=7.31e-13, cumulative_yield_percent=7.31e-13),
#  FPY(name='Co-77', element_name='Cobalt', Z=27, A=77, half_life=0.0, independent_yield_percent=6.53e-13, cumulative_yield_percent=6.53e-13),
#  FPY(name='Tc-118', element_name='Technetium', Z=43, A=118, half_life=0.066, independent_yield_percent=5.89e-13, cumulative_yield_percent=5.89e-13),
#  FPY(name='La-156', element_name='Lanthanum', Z=57, A=156, half_life=0.0, independent_yield_percent=4.87e-13, cumulative_yield_percent=4.87e-13),
#  FPY(name='Ru-121', element_name='Ruthenium', Z=44, A=121, half_life=0.0, independent_yield_percent=3.78e-13, cumulative_yield_percent=3.78e-13),
#  FPY(name='Cs-152', element_name='Cesium', Z=55, A=152, half_life=0.0, independent_yield_percent=1.27e-13, cumulative_yield_percent=1.27e-13),
#  FPY(name='Zr-112', element_name='Zirconium', Z=40, A=112, half_life=0.0, independent_yield_percent=8.89e-14, cumulative_yield_percent=8.89e-14),
#  FPY(name='Y-110', element_name='Yttrium', Z=39, A=110, half_life=0.0, independent_yield_percent=7.9e-14, cumulative_yield_percent=7.9e-14),
#  FPY(name='Co-78', element_name='Cobalt', Z=27, A=78, half_life=0.0, independent_yield_percent=4.28e-14, cumulative_yield_percent=4.28e-14),
#  FPY(name='Nb-114', element_name='Niobium', Z=41, A=114, half_life=0.0, independent_yield_percent=3.74e-14, cumulative_yield_percent=3.74e-14),
#  FPY(name='Mo-117', element_name='Molybdenum', Z=42, A=117, half_life=0.0, independent_yield_percent=2.32e-14, cumulative_yield_percent=2.32e-14),
#  FPY(name='Ce-159', element_name='Cerium', Z=58, A=159, half_life=0.0, independent_yield_percent=1.28e-14, cumulative_yield_percent=1.28e-14),
#  FPY(name='Fe-75', element_name='Iron', Z=26, A=75, half_life=0.0, independent_yield_percent=1e-14, cumulative_yield_percent=1e-14),
#  FPY(name='Tc-119', element_name='Technetium', Z=43, A=119, half_life=0.0, independent_yield_percent=7.58e-15, cumulative_yield_percent=7.58e-15),
#  FPY(name='Pr-161', element_name='Praseodymium', Z=59, A=161, half_life=0.0, independent_yield_percent=7.13e-15, cumulative_yield_percent=7.13e-15),
#  FPY(name='La-157', element_name='Lanthanum', Z=57, A=157, half_life=0.0, independent_yield_percent=5.31e-15, cumulative_yield_percent=5.31e-15),
#  FPY(name='Y-106', element_name='Yttrium', Z=39, A=106, half_life=0.066, independent_yield_percent=4.98e-15, cumulative_yield_percent=4.98e-15),
#  FPY(name='Ag-129', element_name='Silver', Z=47, A=129, half_life=0.046, independent_yield_percent=2.92e-15, cumulative_yield_percent=2.92e-15),
#  FPY(name='Y-107', element_name='Yttrium', Z=39, A=107, half_life=0.03, independent_yield_percent=6.28e-16, cumulative_yield_percent=6.28e-16),
#  FPY(name='Mn-72', element_name='Manganese', Z=25, A=72, half_life=0.0, independent_yield_percent=6.08e-16, cumulative_yield_percent=6.08e-16),
#  FPY(name='Cr-69', element_name='Chromium', Z=24, A=69, half_life=0.0, independent_yield_percent=2.11e-16, cumulative_yield_percent=2.11e-16),
#  FPY(name='Mn-73', element_name='Manganese', Z=25, A=73, half_life=0.0, independent_yield_percent=6.41e-17, cumulative_yield_percent=6.41e-17),
#  FPY(name='Pm-166', element_name='Promethium', Z=61, A=166, half_life=0.0, independent_yield_percent=5.47e-17, cumulative_yield_percent=5.47e-17),
#  FPY(name='Pr-162', element_name='Praseodymium', Z=59, A=162, half_life=0.0, independent_yield_percent=2.96e-17, cumulative_yield_percent=2.96e-17),
#  FPY(name='V-66', element_name='Vanadium', Z=23, A=66, half_life=0.0, independent_yield_percent=2.05e-17, cumulative_yield_percent=2.05e-17),
#  FPY(name='Y-108', element_name='Yttrium', Z=39, A=108, half_life=0.048, independent_yield_percent=9.19e-19, cumulative_yield_percent=9.19e-19),
#  FPY(name='Cr-67', element_name='Chromium', Z=24, A=67, half_life=0.05, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Cr-68', element_name='Chromium', Z=24, A=68, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Cr-70', element_name='Chromium', Z=24, A=70, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Mn-70', element_name='Manganese', Z=25, A=70, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Mn-71', element_name='Manganese', Z=25, A=71, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Fe-74', element_name='Iron', Z=26, A=74, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Fe-76', element_name='Iron', Z=26, A=76, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ni-82', element_name='Nickel', Z=28, A=82, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Cu-79', element_name='Copper', Z=29, A=79, half_life=0.188, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Cu-81', element_name='Copper', Z=29, A=81, half_life=0.028, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Zn-81', element_name='Zinc', Z=30, A=81, half_life=0.32, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ga-66', element_name='Gallium', Z=31, A=66, half_life=34164.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ga-67', element_name='Gallium', Z=31, A=67, half_life=281810.88, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ga-68', element_name='Gallium', Z=31, A=68, half_life=4062.5999999999995, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ge-66', element_name='Germanium', Z=32, A=66, half_life=8136.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ge-67', element_name='Germanium', Z=32, A=67, half_life=1134.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ge-68', element_name='Germanium', Z=32, A=68, half_life=23410080.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ge-69', element_name='Germanium', Z=32, A=69, half_life=140580.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ge-71', element_name='Germanium', Z=32, A=71, half_life=987552.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ge-71m', element_name='Germanium', Z=32, A=71, half_life=0.02041, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='As-69', element_name='Arsenic', Z=33, A=69, half_life=913.8000000000001, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='As-71', element_name='Arsenic', Z=33, A=71, half_life=235080.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='As-72', element_name='Arsenic', Z=33, A=72, half_life=93600.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='As-73', element_name='Arsenic', Z=33, A=73, half_life=6937920.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Se-72', element_name='Selenium', Z=34, A=72, half_life=725760.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Se-73', element_name='Selenium', Z=34, A=73, half_life=25740.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Se-73m', element_name='Selenium', Z=34, A=73, half_life=2388.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Se-75', element_name='Selenium', Z=34, A=75, half_life=10349856.000000002, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Br-75', element_name='Bromine', Z=35, A=75, half_life=5802.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Br-77', element_name='Bromine', Z=35, A=77, half_life=205329.59999999998, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Br-77m', element_name='Bromine', Z=35, A=77, half_life=256.8, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Kr-77', element_name='Krypton', Z=36, A=77, half_life=4464.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Kr-79', element_name='Krypton', Z=36, A=79, half_life=126144.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Kr-79m', element_name='Krypton', Z=36, A=79, half_life=50.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Rb-79', element_name='Rubidium', Z=37, A=79, half_life=1374.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Rb-81', element_name='Rubidium', Z=37, A=81, half_life=16459.2, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Sr-83', element_name='Strontium', Z=38, A=83, half_life=116676.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Sr-105', element_name='Strontium', Z=38, A=105, half_life=0.055600000000000004, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Sr-106', element_name='Strontium', Z=38, A=106, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Sr-107', element_name='Strontium', Z=38, A=107, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Sr-108', element_name='Strontium', Z=38, A=108, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Y-85', element_name='Yttrium', Z=39, A=85, half_life=9648.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Y-97m', element_name='Yttrium', Z=39, A=97, half_life=1.17, independent_yield_percent=1.57, cumulative_yield_percent=0.0),
#  FPY(name='Zr-87', element_name='Zirconium', Z=40, A=87, half_life=6048.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Zr-88', element_name='Zirconium', Z=40, A=88, half_life=7205760.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Nb-89', element_name='Niobium', Z=41, A=89, half_life=7307.999999999999, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Nb-90', element_name='Niobium', Z=41, A=90, half_life=52560.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Nb-91', element_name='Niobium', Z=41, A=91, half_life=21444480000.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Mo-90', element_name='Molybdenum', Z=42, A=90, half_life=20412.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Mo-91', element_name='Molybdenum', Z=42, A=91, half_life=929.4, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Mo-93', element_name='Molybdenum', Z=42, A=93, half_life=126144000000.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Mo-93m', element_name='Molybdenum', Z=42, A=93, half_life=24660.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Mo-116', element_name='Molybdenum', Z=42, A=116, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Tc-93', element_name='Technetium', Z=43, A=93, half_life=9900.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Tc-95', element_name='Technetium', Z=43, A=95, half_life=72000.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Tc-95m', element_name='Technetium', Z=43, A=95, half_life=5270400.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ru-95', element_name='Ruthenium', Z=44, A=95, half_life=5914.8, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ru-97', element_name='Ruthenium', Z=44, A=97, half_life=244512.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ru-122', element_name='Ruthenium', Z=44, A=122, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ru-124', element_name='Ruthenium', Z=44, A=124, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Rh-99', element_name='Rhodium', Z=45, A=99, half_life=1391040.0000000002, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Rh-101m', element_name='Rhodium', Z=45, A=101, half_life=374975.99999999994, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Rh-106m', element_name='Rhodium', Z=45, A=106, half_life=7860.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Rh-108m', element_name='Rhodium', Z=45, A=108, half_life=360.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Pd-99', element_name='Palladium', Z=46, A=99, half_life=1284.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Pd-101', element_name='Palladium', Z=46, A=101, half_life=30492.000000000004, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Pd-103', element_name='Palladium', Z=46, A=103, half_life=1468022.4000000001, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Pd-107m', element_name='Palladium', Z=46, A=107, half_life=21.3, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Pd-125', element_name='Palladium', Z=46, A=125, half_life=0.3987, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Pd-126', element_name='Palladium', Z=46, A=126, half_life=0.2499, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Pd-127', element_name='Palladium', Z=46, A=127, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Pd-129', element_name='Palladium', Z=46, A=129, half_life=0.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ag-103', element_name='Silver', Z=47, A=103, half_life=3942.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ag-105', element_name='Silver', Z=47, A=105, half_life=3567456.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ag-105m', element_name='Silver', Z=47, A=105, half_life=433.8, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ag-106', element_name='Silver', Z=47, A=106, half_life=1437.6000000000001, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ag-106m', element_name='Silver', Z=47, A=106, half_life=715391.9999999999, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ag-107m', element_name='Silver', Z=47, A=107, half_life=44.3, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ag-108', element_name='Silver', Z=47, A=108, half_life=142.92000000000002, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Ag-108m', element_name='Silver', Z=47, A=108, half_life=13812768000.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Cd-105', element_name='Cadmium', Z=48, A=105, half_life=3330.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Cd-107', element_name='Cadmium', Z=48, A=107, half_life=23400.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Cd-109', element_name='Cadmium', Z=48, A=109, half_life=39864960.0, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  FPY(name='Cd-111m', element_name='Cadmium', Z=48, A=111, half_life=2912.4, independent_yield_percent=0.0, cumulative_yield_percent=0.0),
#  ...]

# %%
'''Min and Max mass number A'''

print('Min A = ',min([fpy.A for fpy in fpy_az]))
print('Max A = ',max([fpy.A for fpy in fpy_az]))
# Out:
# Min A =  66
# Max A =  172

# %%
'''Function to plot a 3-D surface plot or a 2D surface plot'''
# to do
# Out:
# 'Function to plot a 3-D surface plot or a 2D surface plot'

# %%
'''Plot FP yield on the A,Z plane'''
# to do
# Out:
# 'Plot FP yield on the A,Z plane'

# %%
'''Plot function for nuclides yield'''

def plot_nuclides(fpy):
    
    from matplotlib import pyplot as plt # import the pyplot function of the matplotlib package
    (fig, ax) = plt.subplots(figsize=(18,7))
    
    ordered_fpy = sorted( fpy, key=lambda entry: entry.Z, reverse=False)

    ax.plot(range(len(fpy)), [nc.cumulative_yield_percent for nc in ordered_fpy], 
            '-.',color='black', marker='o',markersize=10)
    
    ax.set_xlabel('Nuclide',fontsize=18)
    ax.set_ylabel(r'Yield [%]',fontsize=18)
    
    plt.xticks(range(0,len(fpy),2),[nc.name for nc in ordered_fpy][::2],rotation=70,fontsize=12)

    ax.set_xlim((-1,len(fpy)))
    
    # create a twin y axis to reconfigure the top x axis
    ay1 = ax.twiny()
    ay1.set_xlim(ax.get_xlim())
    #ay1.xaxis.tick_top()
    ay1.set_xticks([])
    ay1.set_xticks(range(1,len(fpy),2),[nc.name for nc in ordered_fpy][1::2])
    ay1.set_xticklabels([nc.name for nc in ordered_fpy][1::2],minor=True,fontsize=12,rotation=70)

    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    
    plt.title('Cumulative (Decayed) Fission Products (>1% Yield)',fontsize=22)
    ax.grid(True)
    #plt.yscale('log')
    plt.show()

    return

# %%
'''Generate a list of nuclides with 1% or more fission yield'''

cfpy_1_percent = list() # this list will be used later

for fp in fpy_az:
    if fp.cumulative_yield_percent >= 1.0:
        cfpy_1_percent.append(fp)
        
print('# of FP nuclides = ', len(cfpy_1_percent))
# Out:
# # of FP nuclides =  155

# %%
'''Plot FP nuclides with 1% or more fission yield'''

plot_nuclides(cfpy_1_percent)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9878/3733695765.py in <module>
#       1 '''Plot FP nuclides with 1% or more fission yield'''
#       2
# ----> 3 plot_nuclides(cfpy_1_percent)
#
# /tmp/ipykernel_9878/1108660240.py in plot_nuclides(fpy)
#      23     #ay1.xaxis.tick_top()
#      24     ay1.set_xticks([])
# ---> 25     ay1.set_xticks(range(1,len(fpy),2),[nc.name for nc in ordered_fpy][1::2])
#      26     ay1.set_xticklabels([nc.name for nc in ordered_fpy][1::2],minor=True,fontsize=12,rotation=70)
#      27
#
# /usr/lib/python3.9/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# TypeError: set_ticks() takes 2 positional arguments but 3 were given

# %%
'''Plot function for nuclides half-life'''

def plot_nuclides(fpy):
    
    from matplotlib import pyplot as plt # import the pyplot function of the matplotlib package
    (fig, ax) = plt.subplots(figsize=(18,7))

    ordered_fpy = sorted( fpy, key=lambda entry: entry.Z, reverse=False)
    
    ax.plot( [nc.Z for nc in ordered_fpy], [nc.half_life/3600/24/365 for nc in ordered_fpy], 
             ' ',color='black', marker='x',markersize=10 )
    
    #plt.xticks(range(0,len(nuclides),20),[nc.symbol for nc in nuclides.values()][::20],rotation=0,fontsize=12)
    min_z = min([nc.Z for nc in ordered_fpy])
    max_z = max([nc.Z for nc in ordered_fpy])

    ax.xaxis.set_ticks(range(min_z, max_z+1,2))
    ax.set_xlim((min_z-1,max_z+1))

    plt.xlabel(r'Nuclide Z Number',fontsize=18)
    plt.ylabel(r'$T_{1/2} [a]$',fontsize=18)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=16)
    
    # create a twin y axis to reconfigure the top x axis
    ay1 = ax.twiny()
    ay1.set_xlim(ax.get_xlim())
    #ay1.xaxis.tick_top()
    ay1.set_xticks([])
    from mendeleev import element
    #ay1.set_xticks(range(0,len(atoms),2),[atm.symbol for atm in atoms][::2],rotation=0,fontsize=12)
    ay1.set_xticks(range(min_z,max_z+1), [element(z).symbol for z in range(min_z,max_z+1)])
    ay1.set_xticklabels([element(z).symbol for z in range(min_z,max_z+1)],minor=True,fontsize=12)

    min_a = min([nc.A for nc in ordered_fpy])
    max_a = max([nc.A for nc in ordered_fpy])
    
    plt.title(r'%i Nuclides: $%i \leq A \leq %i$ '%(len(fpy),min_a,max_a),fontsize=22)
    ax.grid(True)
    plt.yscale('log')
    plt.show()

    return

# %%
'''Plot half-life of nuclides'''

plot_nuclides(fpy_az)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9878/1161482430.py in <module>
#       1 '''Plot half-life of nuclides'''
#       2
# ----> 3 plot_nuclides(fpy_az)
#
# /tmp/ipykernel_9878/435795624.py in plot_nuclides(fpy)
#      30     from mendeleev import element
#      31     #ay1.set_xticks(range(0,len(atoms),2),[atm.symbol for atm in atoms][::2],rotation=0,fontsize=12)
# ---> 32     ay1.set_xticks(range(min_z,max_z+1), [element(z).symbol for z in range(min_z,max_z+1)])
#      33     ay1.set_xticklabels([element(z).symbol for z in range(min_z,max_z+1)],minor=True,fontsize=12)
#      34
#
# /usr/lib/python3.9/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# TypeError: set_ticks() takes 2 positional arguments but 3 were given

# %% [markdown]
# ## Cumulative fission products half-life times<a id="cfphalflife"></a>
#
# For those with >=1%, >=0.1%, and >=0% yields.

# %%
'''Function to compute half-life times of given nuclides'''

def half_life_times(fp_list):

    ordered_fp_list = sorted( fp_list, key=lambda entry: entry.Z, reverse=False )
    #print(ordered_fp_list)
    
    half_life_1_10       = list()
    half_life_10_100     = list()
    half_life_100_1000   = list()
    half_life_1000_1M    = list()
    half_life_1M_10M     = list()
    half_life_10M_100M   = list()
    half_life_100M_infty = list()
     
    z_0 = 0
    for fp in ordered_fp_list:
        
        h_f_y = fp.half_life/3600/24/365
        name = fp.name
        element_name = fp.element_name
        
        assert fp.Z >= z_0
        z_0 = fp.Z
    
        save = (name,element_name)
        
        if h_f_y >= 1 and h_f_y < 10:
            half_life_1_10.append(save)
        elif h_f_y >= 10 and h_f_y < 100:
            half_life_10_100.append(save)
        elif h_f_y >= 100 and h_f_y < 1000:
            half_life_100_1000.append(save)
        elif h_f_y >= 1000 and h_f_y < 1e+6:
            half_life_1000_1M.append(save)
        elif h_f_y >= 1e+6 and h_f_y < 10e+6:
            half_life_1M_10M.append(save)
        elif h_f_y >= 10e+6 and h_f_y < 100e+6:
            half_life_10M_100M.append(save)
        else:
            half_life_100M_infty.append(save)
            
    print('|  Half-Life       |  FP Nuclides   |')
    print('|:-----------------|:------------|')
    nuclides = str()
    for ele in half_life_1_10:
        nuclides += ele[0]+', '
    print('|1 to 10 y         |', nuclides[:-2],'|')
    nuclides = str()
    for ele in half_life_10_100:
        nuclides += ele[0]+', '
    print('|10 to 100 y       |', nuclides[:-2],'|')
    nuclides = str()
    for ele in half_life_100_1000:
        nuclides += ele[0]+', '
    print('|100 to 1 ky       |', nuclides[:-2],'|')
    nuclides = str()
    for ele in half_life_1000_1M:
        nuclides += ele[0]+', '
    print('|1 ky to 1 My      |', nuclides[:-2],'|')
    nuclides = str()
    for ele in half_life_1M_10M:
        nuclides += ele[0]+', '
    print('|1 My to 10 My     |', nuclides[:-2],'|')
    nuclides = str()
    for ele in half_life_10M_100M:
        nuclides += ele[0]+', '
    print('|10 My to 100 My    |', nuclides[:-2],'|')
    nuclides = str()
    for ele in half_life_100M_infty:
        nuclides += ele[0]+', '
    #print('|100 My or greater  |', nuclides[:-2],'|')

    #print('')
    #print('1   to 10   years = ',half_life_1_10)
    #print('10  to 100  years = ',half_life_10_100)
    #print('100 to 1k   years = ',half_life_100_1000)
    #print('1k  to 1M   years = ',half_life_1000_1M)
    #print('1M  to 10M  years = ',half_life_1M_10M)
    #print('10M to 100M years = ',half_life_10M_100M)
    #print('100M to --> years = ',half_life_100M_infty)
    
    return

# %%
'''Compute half-life times of cumulative FP with >1% yield'''

print('total # of FP nuclides = ', len(cfpy_1_percent))
print('')

half_life_times( cfpy_1_percent ) # call the function
# Out:
# total # of FP nuclides =  155
#
# |  Half-Life       |  FP Nuclides   |
# |:-----------------|:------------|
# |1 to 10 y         | Pm-147 |
# |10 to 100 y       | Sr-90, Nb-93m, Cs-137 |
# |100 to 1 ky       |  |
# |1 ky to 1 My      | Tc-99 |
# |1 My to 10 My     | Zr-93, Cs-135 |
# |10 My to 100 My    |  |

# %% [markdown]
# |  Half-Life       |  $^{235}$U FP Nuclides   |
# |:-----------------|:------------|
# |1 to 10 y         | Pm-147 |
# |10 to 100 y       | Sr-90, Nb-93m, Cs-137 |
# |100 to 1 ky       |  |
# |1 ky to 1 My      | Tc-99 |
# |1 My to 10 My     | Zr-93, Cs-135 |
# |10 My to 100 My    |  |

# %%
'''Compute half-life times of cumulative FP with >0.1% yield'''

cfpy_0dot1_percent = list()

for fp in fpy_az:
    if fp.cumulative_yield_percent >= 0.1:
        cfpy_0dot1_percent.append(fp)
        
print('total # of FP nuclides = ', len(cfpy_0dot1_percent))
print('')

half_life_times( cfpy_0dot1_percent )
# Out:
# total # of FP nuclides =  265
#
# |  Half-Life       |  FP Nuclides   |
# |:-----------------|:------------|
# |1 to 10 y         | Ru-106, Pm-147 |
# |10 to 100 y       | Kr-85, Sr-90, Nb-93m, Cs-137, Sm-151 |
# |100 to 1 ky       |  |
# |1 ky to 1 My      | Tc-99 |
# |1 My to 10 My     | Zr-93, Pd-107, Cs-135 |
# |10 My to 100 My    | I-129 |

# %% [markdown]
# |  Half-Life       | $^{235}$U FP Nuclides   |
# |:-----------------|:------------|
# |1 to 10 y         | Ru-106, Pm-147 |
# |10 to 100 y       | Kr-85, Sr-90, Nb-93m, Cs-137, Sm-151 |
# |100 to 1 ky       |  |
# |1 ky to 1 My      | Tc-99 |
# |1 My to 10 My     | Zr-93, Pd-107, Cs-135 |
# |10 My to 100 My    | I-129 |

# %%
'''Compute half-life times of cumulative FP all yields'''

print('total # of FP nuclides = ', len(fpy_az))
print('')

half_life_times( fpy_az ) # call the function
# Out:
# total # of FP nuclides =  1111
#
# |  Half-Life       |  FP Nuclides   |
# |:-----------------|:------------|
# |1 to 10 y         | Ru-106, Rh-102m, Rh-101, Cd-109, Sb-125, Cs-134, Pm-147, Pm-146, Eu-155, Eu-154, Tm-171, Hf-172 |
# |10 to 100 y       | Kr-85, Sr-90, Nb-93m, Cd-113m, Sn-121m, Cs-137, Ba-133, Pm-145, Sm-151, Eu-152, Tb-157 |
# |100 to 1 ky       | Nb-91, Ag-108m, Tb-158 |
# |1 ky to 1 My      | Se-79, Kr-81, Nb-94, Mo-93, Tc-99, Sn-126, La-137, Ho-166m, Ho-163 |
# |1 My to 10 My     | Zr-93, Tc-98, Tc-97, Pd-107, Cs-135 |
# |10 My to 100 My    | Nb-92, I-129 |

# %% [markdown]
# |  Half-Life       |  $^{235}$U FP Nuclides   |
# |:-----------------|:------------|
# |1 to 10 y         | Ru-106, Rh-102m, Rh-101, Cd-109, Sb-125, Cs-134, Pm-147, Pm-146, Eu-155, Eu-154, Tm-171, Hf-172 |
# |10 to 100 y       | Kr-85, Sr-90, Nb-93m, Cd-113m, Sn-121m, Cs-137, Ba-133, Pm-145, Sm-151, Eu-152, Tb-157 |
# |100 to 1 ky       | Nb-91, Ag-108m, Tb-158 |
# |1 ky to 1 My      | Se-79, Kr-81, Nb-94, Mo-93, Tc-99, Sn-126, La-137, Ho-166m, Ho-163 |
# |1 My to 10 My     | Zr-93, Tc-98, Tc-97, Pd-107, Cs-135 |
# |10 My to 100 My    | Nb-92, I-129 |
